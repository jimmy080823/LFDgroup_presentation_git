# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import missingno as msno
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV
import time

# %%
csv = pd.read_csv('lfd_2023_group2test.csv')
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grams       4751 non-null   float64
#  1   width_cm    5000 non-null   int64
#  2   length_cm   5000 non-null   int64
#  3   wavelength  5000 non-null   int64
#  4   country     5000 non-null   object
#  5   cost        5000 non-null   int64
#  6   recoil      5000 non-null   float64
#  7   y_offset    5000 non-null   float64
#  8   shape       5000 non-null   object
#  9   distance    5000 non-null   float64
#  10  target      5000 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 429.8+ KB

# %%
msno.matrix(csv.sample(5000))
# Out:
# <Axes: >

# %%
csv2 = csv.dropna()
csv3 = csv2.drop_duplicates()
csv3.info()
msno.matrix(csv3.sample(4751))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4751 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grams       4751 non-null   float64
#  1   width_cm    4751 non-null   int64
#  2   length_cm   4751 non-null   int64
#  3   wavelength  4751 non-null   int64
#  4   country     4751 non-null   object
#  5   cost        4751 non-null   int64
#  6   recoil      4751 non-null   float64
#  7   y_offset    4751 non-null   float64
#  8   shape       4751 non-null   object
#  9   distance    4751 non-null   float64
#  10  target      4751 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 445.4+ KB
# <Axes: >

# %%
X = csv3.iloc[:, :-1].values
y = csv3.iloc[:, -1].values

# %%
y
# Out:
# array(['widget7', 'widget1', 'widget5', ..., 'widget4', 'widget2',
#        'widget8'], dtype=object)

# %%
ct = ColumnTransformer(transformers=[
    ('encoder_4', OneHotEncoder(), [4]),
    ('encoder_8', OneHotEncoder(), [8])
], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X
# Out:
# array([[1.0, 0.0, 1.0, ..., 19.7, 28.7, 48.41],
#        [1.0, 0.0, 1.0, ..., 43.28, -27.19, 39.84],
#        [1.0, 0.0, 0.0, ..., 60.54, -72.91, 47.33],
#        ...,
#        [1.0, 0.0, 1.0, ..., 62.07, 14.78, 34.24],
#        [1.0, 0.0, 1.0, ..., 28.24, -102.8, 43.03],
#        [1.0, 0.0, 1.0, ..., 73.94, -50.94, 49.93]], dtype=object)

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([6, 0, 4, ..., 3, 1, 7])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
# array([[1.0, 0.0, 1.0, ..., 24.09, 20.39, 42.91],
#        [1.0, 0.0, 1.0, ..., 52.39, -20.58, 31.67],
#        [1.0, 0.0, 1.0, ..., 75.19, 2.58, 48.71],
#        ...,
#        [1.0, 0.0, 1.0, ..., 62.84, -108.54, 35.36],
#        [1.0, 0.0, 1.0, ..., 67.43, 68.0, 53.91],
#        [1.0, 0.0, 1.0, ..., 70.82, -79.58, 52.01]], dtype=object)

# %%
X_test
# Out:
# array([[1.0, 0.0, 0.0, ..., 68.76, 45.44, 48.03],
#        [1.0, 0.0, 1.0, ..., 25.98, -22.3, 36.48],
#        [1.0, 0.0, 1.0, ..., 60.24, -4.77, 45.08],
#        ...,
#        [1.0, 0.0, 1.0, ..., 52.74, -71.7, 35.12],
#        [1.0, 0.0, 1.0, ..., 24.01, -59.64, 45.23],
#        [1.0, 0.0, 1.0, ..., 37.16, -127.63, 32.64]], dtype=object)

# %%
y_train
# Out:
# array([1, 3, 7, ..., 7, 8, 7])

# %%
y_test
# Out:
# array([7, 0, 7, 0, 4, 6, 8, 8, 8, 1, 0, 6, 2, 1, 7, 2, 8, 8, 2, 1, 5, 2,
#        2, 6, 6, 1, 5, 6, 8, 0, 6, 3, 4, 2, 1, 3, 2, 6, 6, 6, 6, 8, 3, 4,
#        0, 8, 3, 2, 2, 0, 8, 4, 5, 3, 8, 3, 6, 6, 5, 6, 6, 6, 2, 3, 7, 3,
#        6, 6, 3, 4, 5, 2, 6, 5, 3, 0, 1, 8, 0, 6, 7, 3, 0, 4, 2, 1, 2, 6,
#        1, 4, 2, 5, 8, 2, 5, 0, 8, 1, 0, 2, 6, 7, 3, 8, 6, 8, 5, 6, 8, 7,
#        1, 0, 1, 2, 4, 8, 2, 8, 0, 2, 2, 1, 8, 7, 2, 5, 4, 3, 6, 1, 3, 0,
#        3, 1, 8, 8, 8, 2, 3, 7, 2, 4, 2, 3, 5, 2, 3, 1, 6, 7, 6, 5, 3, 7,
#        3, 0, 3, 8, 5, 5, 4, 2, 5, 2, 6, 8, 5, 8, 3, 4, 5, 2, 1, 2, 7, 6,
#        0, 0, 0, 2, 7, 0, 7, 5, 4, 8, 2, 7, 5, 0, 0, 8, 8, 2, 3, 3, 5, 2,
#        0, 8, 7, 2, 7, 8, 6, 0, 8, 4, 4, 5, 2, 3, 8, 8, 4, 7, 4, 0, 6, 0,
#        1, 6, 1, 3, 3, 2, 1, 8, 2, 5, 7, 3, 1, 8, 7, 5, 7, 1, 1, 0, 5, 0,
#        5, 0, 4, 4, 6, 5, 6, 5, 8, 3, 8, 8, 4, 6, 5, 2, 2, 3, 2, 7, 0, 7,
#        5, 2, 5, 4, 2, 7, 3, 6, 1, 3, 6, 7, 1, 2, 2, 6, 7, 4, 8, 1, 7, 5,
#        1, 3, 7, 8, 1, 1, 6, 4, 2, 2, 2, 5, 8, 7, 1, 6, 6, 0, 5, 3, 1, 0,
#        7, 4, 4, 3, 5, 1, 7, 0, 5, 1, 0, 3, 4, 2, 8, 1, 6, 0, 3, 6, 2, 6,
#        8, 7, 0, 1, 2, 6, 3, 3, 5, 1, 8, 8, 0, 4, 7, 4, 6, 0, 8, 6, 3, 2,
#        4, 1, 3, 3, 4, 1, 7, 0, 1, 5, 1, 5, 3, 2, 2, 5, 2, 0, 0, 2, 3, 2,
#        7, 6, 5, 5, 2, 5, 3, 2, 2, 1, 5, 4, 2, 6, 0, 2, 3, 3, 1, 4, 6, 6,
#        1, 0, 8, 5, 3, 1, 3, 8, 7, 2, 4, 0, 6, 2, 4, 7, 4, 7, 3, 7, 5, 3,
#        5, 5, 6, 1, 8, 2, 8, 8, 1, 3, 2, 1, 1, 0, 3, 0, 3, 6, 5, 4, 8, 7,
#        0, 3, 3, 1, 6, 4, 3, 7, 6, 5, 8, 5, 8, 6, 4, 4, 0, 6, 5, 6, 6, 1,
#        4, 4, 0, 2, 5, 2, 4, 5, 4, 1, 0, 6, 7, 8, 2, 0, 6, 1, 6, 8, 4, 0,
#        6, 0, 6, 0, 4, 1, 2, 3, 5, 4, 4, 0, 1, 7, 1, 0, 8, 5, 4, 6, 0, 1,
#        5, 3, 5, 1, 4, 1, 6, 3, 8, 3, 8, 1, 6, 8, 4, 3, 5, 7, 2, 5, 5, 6,
#        5, 5, 8, 2, 0, 1, 8, 8, 7, 4, 2, 2, 5, 5, 4, 7, 6, 3, 3, 8, 6, 7,
#        1, 7, 2, 3, 5, 8, 1, 1, 6, 0, 6, 8, 3, 0, 5, 3, 1, 1, 1, 7, 6, 2,
#        7, 2, 0, 1, 4, 6, 7, 3, 2, 4, 7, 7, 6, 2, 5, 7, 0, 3, 7, 3, 4, 0,
#        5, 6, 8, 7, 0, 4, 3, 8, 4, 7, 2, 3, 5, 1, 3, 3, 8, 7, 2, 3, 2, 2,
#        2, 7, 0, 2, 6, 3, 2, 4, 3, 8, 5, 1, 2, 3, 1, 1, 6, 3, 1, 6, 2, 6,
#        8, 8, 7, 4, 5, 7, 3, 4, 5, 2, 3, 8, 6, 1, 7, 4, 3, 0, 0, 5, 7, 2,
#        6, 6, 1, 5, 7, 2, 8, 0, 7, 4, 6, 2, 6, 6, 5, 0, 7, 6, 3, 0, 2, 3,
#        1, 3, 4, 8, 5, 2, 2, 5, 7, 6, 5, 7, 5, 8, 2, 0, 0, 1, 4, 4, 0, 4,
#        6, 3, 8, 2, 1, 5, 4, 2, 8, 2, 1, 1, 6, 7, 0, 8, 7, 6, 1, 0, 0, 3,
#        4, 0, 3, 7, 6, 8, 5, 3, 5, 5, 7, 4, 3, 0, 8, 8, 7, 8, 3, 2, 7, 6,
#        0, 4, 7, 8, 7, 4, 1, 4, 2, 7, 7, 3, 1, 7, 8, 7, 1, 5, 4, 4, 1, 3,
#        6, 5, 5, 2, 1, 1, 6, 2, 3, 4, 7, 5, 4, 3, 7, 3, 2, 4, 1, 2, 7, 6,
#        8, 0, 1, 6, 5, 2, 0, 7, 7, 2, 0, 2, 7, 4, 0, 2, 6, 4, 3, 6, 4, 2,
#        2, 0, 1, 1, 1, 6, 5, 3, 4, 8, 8, 3, 3, 7, 3, 3, 7, 6, 1, 5, 4, 5,
#        8, 5, 6, 0, 5, 0, 0, 6, 5, 3, 8, 8, 7, 3, 2, 1, 1, 2, 6, 5, 1, 4,
#        7, 8, 1, 0, 5, 0, 3, 1, 4, 6, 2, 3, 0, 2, 8, 7, 7, 4, 5, 3, 4, 6,
#        0, 0, 8, 7, 7, 1, 0, 5, 6, 0, 7, 6, 7, 8, 1, 3, 2, 3, 4, 3, 2, 5,
#        8, 8, 0, 3, 4, 6, 3, 0, 2, 1, 4, 4, 6, 5, 1, 4, 7, 7, 7, 8, 6, 8,
#        1, 4, 6, 4, 0, 6, 5, 0, 6, 0, 2, 6, 1, 0, 4, 5, 8, 4, 3, 1, 8, 6,
#        2, 6, 4, 6, 0])

# %%
sc = StandardScaler()
X_train[:, 16:] = sc.fit_transform(X_train[:, 16:])
X_test[:, 16:] = sc.transform(X_test[:, 16:])

# %%
X_train
# Out:
# array([[1.0, 0.0, 1.0, ..., -1.3605606964284784, 0.44001644617005986,
#         0.3396859375552734],
#        [1.0, 0.0, 1.0, ..., 0.4570477288486637, -0.1330944689207881,
#         -0.8376167093765304],
#        [1.0, 0.0, 1.0, ..., 1.9214107004500358, 0.19088036128433855,
#         0.9471908621286248],
#        ...,
#        [1.0, 0.0, 1.0, ..., 1.1282140908326261, -1.363527373274974,
#         -0.45111788667382974],
#        [1.0, 0.0, 1.0, ..., 1.4230134785365869, 1.1060113367601325,
#         1.4918504496771459],
#        [1.0, 0.0, 1.0, ..., 1.640741130893106, -0.9584189500132956,
#         1.2928402157651862]], dtype=object)

# %%
X_test
# Out:
# array([[1.0, 0.0, 0.0, ..., 1.5084346518800003, 0.7904296368712007,
#         0.8759661468338181],
#        [1.0, 0.0, 1.0, ..., -1.2391727132562593, -0.1571547758272138,
#         -0.33380659089414844],
#        [1.0, 0.0, 1.0, ..., 0.9612253309131714, 0.08806451491094991,
#         0.5669765731284065],
#        ...,
#        [1.0, 0.0, 1.0, ..., 0.4795269849916673, -0.8481891718606015,
#         -0.4762560214837617],
#        [1.0, 0.0, 1.0, ..., -1.3656988121183076, -0.6794872525050821,
#         0.5826879073846137],
#        [1.0, 0.0, 1.0, ..., -0.5211210456026042, -1.6305688028352445,
#         -0.7360167478530563]], dtype=object)

# %% [markdown]
# ## Naive Bayes

# %%
start_time = time.time()

model = GaussianNB()
model.fit(X_train, y_train)

nb_training_time = time.time() - start_time
print('Training Time:', nb_training_time)
naive=[0.004, 0.0041, 0.0055, 0.005, 0.006]
# Out:
# Training Time: 0.003999948501586914

# %%
y_pred = model.predict(X_test)
np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)
# Out:
# array([[7, 7],
#        [0, 0],
#        [7, 7],
#        ...,
#        [2, 4],
#        [6, 6],
#        [6, 0]])

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.8464773922187171

# %% [markdown]
# ## Random Forest (RandomForestClassifier)

# %%
rf=[]
rf_store=[1.6908, 1.7149, 1.6753, 1.6596, 1.6712]
ir=range(1,6)

for i in ir:
    start_time = time.time()

    model = RandomForestClassifier(n_estimators = 184, criterion = 'entropy',random_state=1)
    model.fit(X_train, y_train)

    rf_training_time = time.time() - start_time
    print('RF Training Time:', rf_training_time)
    rf.append(rf_training_time)
    i = i+1
rf
# Out:
# RF Training Time: 1.8941190242767334
# RF Training Time: 1.8599777221679688
# RF Training Time: 1.8177587985992432
# RF Training Time: 1.8248887062072754
# RF Training Time: 1.8285033702850342
# [1.8941190242767334,
#  1.8599777221679688,
#  1.8177587985992432,
#  1.8248887062072754,
#  1.8285033702850342]

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)


# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
accuracy_score(y_test, y_pred)
# Out:
# 0.9768664563617245

# %%
n_estimators_range = range(1, 201)  # Range of number of estimators
ir=range(1,5)
scores = []
rftime = []
rftimestore=[256.6549, 220.9797, 191.2911, 190.954, 191.2381, 210.3]

#for i in ir:
#    start_time = time.time()
    # Run the loop over the range of n_estimators

for n_estimators in n_estimators_range:
    model = RandomForestClassifier(n_estimators = n_estimators, criterion = 'entropy',random_state=1)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    scores.append(score)

#    rf_time = time.time() - start_time
#    rftime.append(rf_time)

#rftime

# %%
plt.plot(n_estimators_range, scores)
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy Score')
plt.title('Accuracy vs Number of Estimators')
plt.show()

# %%
rf_grid = []
ir=range(1,5)
rf_grid_store=[856.1625998020172, 819.738733291626, 791.0501453876495, 1127.1114888191223, 883.5797]

#for i in ir:
start_time = time.time()

parameter = {'n_estimators': range(1, 201)}
model = RandomForestClassifier(criterion='entropy', random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=parameter, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_n_estimators = grid_search.best_estimator_.get_params()['n_estimators']
print(f"The best number of estimators is: {best_n_estimators}")

rf_gridtime = time.time() - start_time
rf_grid.append(rf_gridtime)

rf_grid
# Out:
# The best number of estimators is: 98
# [883.5797476768494]

# %% [markdown]
# ## Random Forest (Bagging)

# %%
start_time = time.time()
decisiontree = DecisionTreeClassifier()
model = BaggingClassifier(decisiontree, n_estimators=177, max_samples=0.8, random_state=1)
model.fit(X_train, y_train)

bagtime = time.time()-start_time


bagging = [1.2, 1.2, 1.2, 1.2, 1.2] #estimator=41  0.9516
bagging2= [5.9, 6, 6.1, 6, 5.9]     #estimator=198 0.947
bagging3= [5.3941, 5.4292, 5.3894, 5.4168, 5.3927] #estimator=177 0.9464

bagtime
# Out:
# 5.392724275588989

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)


# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.9463722397476341

# %%
n_estimators_range = range(1, 101)  # Range of number of estimators
scores = []
rfbegging_time = []
rfbegging_store=[207.99422812461853, 203.456063747406, 203.19898295402527, 184.71264696121216, 151.15020418167114]
ir=range(1,6)

# Run the loop over the range of n_estimators
for i in ir:
    start_time = time.time()
    
    for n_estimators in n_estimators_range:
        model = BaggingClassifier(DecisionTreeClassifier(), 
                                        n_estimators=n_estimators, 
                                        max_samples=0.8, 
                                        random_state=1)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)

    rf_begtime = time.time() - start_time
    rfbegging_time.append(rf_begtime)

rfbegging_time
# Out:
# [207.99422812461853,
#  203.456063747406,
#  203.19898295402527,
#  184.71264696121216,
#  151.15020418167114]

# %%
plt.plot(n_estimators_range, scores)
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy Score')
plt.title('Accuracy vs Number of Estimators')
plt.show()

# %%
begging_grid=[]
ir=range(1,6)
begging_grid_store=[2407, 2379.82, 2376.95, 2378.08, 2376.1]

for i in ir:
    start_time = time.time()
    
    parameter = {'n_estimators': range(1, 201)}
    decisiontree = DecisionTreeClassifier()
    model = BaggingClassifier(decisiontree, max_samples=0.8, random_state=1)
    grid_search = GridSearchCV(estimator=model, param_grid=parameter, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)
    best_n_estimators = grid_search.best_estimator_.get_params()['n_estimators']
    print(f"The best number of estimators is: {best_n_estimators}")
    
    begging_grid_time = time.time() - start_time
    begging_grid.append(begging_grid_time)
    print('Training Time:', begging_grid_time)

begging_grid
# Out:
# The best number of estimators is: 177
# Training Time: 2406.994882106781
# The best number of estimators is: 177
# Training Time: 2379.817266702652
# The best number of estimators is: 177
# Training Time: 2376.9545772075653
# The best number of estimators is: 177
# Training Time: 2378.0801780223846
# The best number of estimators is: 177
# Training Time: 2376.1038863658905
# [2406.994882106781,
#  2379.817266702652,
#  2376.9545772075653,
#  2378.0801780223846,
#  2376.1038863658905]

# %% [markdown]
# ## Kernel SVM (rbf)

# %%
rbf=[0.0756, 0.07814, 0.071, 0.076, 0.074]
start_time = time.time()

model = SVC(kernel = 'rbf', random_state = 1, C=100, gamma = 0.0001)
model.fit(X_train, y_train)

rbf_time = time.time() - start_time

rbf_time
# Out:
# 0.07401657104492188

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.9852786540483701

# %%
rbf_gridtime=[20.101, 19.8311, 19.625, 19.8626, 19.806]

start_time = time.time()
model = SVC(kernel='rbf',random_state=1)

parameters = {
              'C': [0.1, 1, 100, 1000],
              'gamma': [0.0001, 0.001, 0.1, 1, 3, 5]
             }
gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
gridsearch.fit(X_train, y_train)

rbf_grid_time = time.time() - start_time
rbf_grid_time
# Out:
# 19.805904626846313

# %%
gridsearch.best_params_
# Out:
# {'C': 100, 'gamma': 0.0001}

# %% [markdown]
# ## Kernel SVM (Poly)

# %%
polytime=[0.1417, 0.1574, 0.1386, 0.1385, 0.1428]
start_time = time.time()

model = SVC(C=0.1, kernel='poly', random_state = 1)
model.fit(X_train, y_train)

poly_time = time.time() - start_time
poly_time
# Out:
# 0.14277982711791992

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.92534174553102

# %%
model = SVC(kernel='poly',random_state=1)

ir=range(1, 6)
polygridtime=[1.361783504486084, 1.3541688919067383, 1.3621025085449219, 1.3611788749694824, 1.3609387874603271]


for i in ir:
    start_time = time.time()
    parameters = {
                'C': [0.1, 1, 100, 1000],
                }
    gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
    gridsearch.fit(X_train, y_train)

    poly_grid_time = time.time() - start_time
    polygridtime.append(poly_grid_time)

polygridtime
# Out:
# [1.361783504486084,
#  1.3541688919067383,
#  1.3621025085449219,
#  1.3611788749694824,
#  1.3609387874603271]

# %%
gridsearch.best_params_
# Out:
# {'C': 1}

# %% [markdown]
# ## Kernel SVM (linear)

# %%
linear = []
ir=range(1, 6)
linear_store=[0.03, 0.029, 0.0289, 0.029, 0.0291]

for i in ir:
    start_time = time.time()
    model = SVC(C=1, kernel='linear', random_state = 1)
    model.fit(X_train, y_train)
    linear_time = time.time() - start_time
    linear.append(linear_time)
linear
# Out:
# [0.0299990177154541,
#  0.029017210006713867,
#  0.028980493545532227,
#  0.029001235961914062,
#  0.029099464416503906]

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.9852786540483701

# %%
linear_grid=[]
ir=range(1, 6)
linear_grid_store=[0.9889, 1.0167, 1.0831, 1.0691, 1.0678]

model = SVC(kernel='linear',random_state=1)

for i in ir:
    start_time = time.time()

    parameters = {
                'C': [0.1, 1, 10, 100, 1000],
                }
    gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
    gridsearch.fit(X_train, y_train)
    linear_grid_time = time.time() - start_time
    linear_grid.append(linear_grid_time)

linear_grid
# Out:
# [0.9889969825744629,
#  1.01674222946167,
#  1.0831429958343506,
#  1.0691328048706055,
#  1.0678441524505615]

# %%
gridsearch.best_params_
# Out:
# {'C': 1}
