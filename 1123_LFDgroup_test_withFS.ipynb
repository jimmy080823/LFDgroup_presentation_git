# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import missingno as msno
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV
import time

# %%
csv = pd.read_csv('lfd_2023_group2test.csv')
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grams       4751 non-null   float64
#  1   width_cm    5000 non-null   int64
#  2   length_cm   5000 non-null   int64
#  3   wavelength  5000 non-null   int64
#  4   country     5000 non-null   object
#  5   cost        5000 non-null   int64
#  6   recoil      5000 non-null   float64
#  7   y_offset    5000 non-null   float64
#  8   shape       5000 non-null   object
#  9   distance    5000 non-null   float64
#  10  target      5000 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 429.8+ KB

# %%
msno.matrix(csv.sample(5000))
# Out:
# <Axes: >

# %%
csv2 = csv.dropna()
csv3 = csv2.drop_duplicates()
csv3.info()
msno.matrix(csv3.sample(4751))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4751 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grams       4751 non-null   float64
#  1   width_cm    4751 non-null   int64
#  2   length_cm   4751 non-null   int64
#  3   wavelength  4751 non-null   int64
#  4   country     4751 non-null   object
#  5   cost        4751 non-null   int64
#  6   recoil      4751 non-null   float64
#  7   y_offset    4751 non-null   float64
#  8   shape       4751 non-null   object
#  9   distance    4751 non-null   float64
#  10  target      4751 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 445.4+ KB
# <Axes: >

# %%
X = csv3.iloc[:, :-1].values
y = csv3.iloc[:, -1].values

# %%
y
# Out:
# array(['widget7', 'widget1', 'widget5', ..., 'widget4', 'widget2',
#        'widget8'], dtype=object)

# %%
ct = ColumnTransformer(transformers=[
    ('encoder_4', OneHotEncoder(), [4]),
    ('encoder_8', OneHotEncoder(), [8])
], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X
# Out:
# array([[0.0, 0.0, 1.0, ..., 19.7, 28.7, 48.41],
#        [0.0, 0.0, 0.0, ..., 43.28, -27.19, 39.84],
#        [0.0, 0.0, 0.0, ..., 60.54, -72.91, 47.33],
#        ...,
#        [1.0, 0.0, 0.0, ..., 62.07, 14.78, 34.24],
#        [0.0, 0.0, 0.0, ..., 28.24, -102.8, 43.03],
#        [0.0, 1.0, 0.0, ..., 73.94, -50.94, 49.93]], dtype=object)

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([6, 0, 4, ..., 3, 1, 7])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
# array([[0.0, 0.0, 1.0, ..., 24.09, 20.39, 42.91],
#        [0.0, 0.0, 0.0, ..., 52.39, -20.58, 31.67],
#        [0.0, 1.0, 0.0, ..., 75.19, 2.58, 48.71],
#        ...,
#        [1.0, 0.0, 0.0, ..., 62.84, -108.54, 35.36],
#        [0.0, 0.0, 0.0, ..., 67.43, 68.0, 53.91],
#        [0.0, 0.0, 0.0, ..., 70.82, -79.58, 52.01]], dtype=object)

# %%
X_test
# Out:
# array([[0.0, 0.0, 0.0, ..., 68.76, 45.44, 48.03],
#        [0.0, 0.0, 0.0, ..., 25.98, -22.3, 36.48],
#        [0.0, 0.0, 0.0, ..., 60.24, -4.77, 45.08],
#        ...,
#        [0.0, 0.0, 0.0, ..., 52.74, -71.7, 35.12],
#        [0.0, 0.0, 0.0, ..., 24.01, -59.64, 45.23],
#        [0.0, 0.0, 0.0, ..., 37.16, -127.63, 32.64]], dtype=object)

# %%
y_train
# Out:
# array([1, 3, 7, ..., 7, 8, 7])

# %%
y_test
# Out:
# array([7, 0, 7, 0, 4, 6, 8, 8, 8, 1, 0, 6, 2, 1, 7, 2, 8, 8, 2, 1, 5, 2,
#        2, 6, 6, 1, 5, 6, 8, 0, 6, 3, 4, 2, 1, 3, 2, 6, 6, 6, 6, 8, 3, 4,
#        0, 8, 3, 2, 2, 0, 8, 4, 5, 3, 8, 3, 6, 6, 5, 6, 6, 6, 2, 3, 7, 3,
#        6, 6, 3, 4, 5, 2, 6, 5, 3, 0, 1, 8, 0, 6, 7, 3, 0, 4, 2, 1, 2, 6,
#        1, 4, 2, 5, 8, 2, 5, 0, 8, 1, 0, 2, 6, 7, 3, 8, 6, 8, 5, 6, 8, 7,
#        1, 0, 1, 2, 4, 8, 2, 8, 0, 2, 2, 1, 8, 7, 2, 5, 4, 3, 6, 1, 3, 0,
#        3, 1, 8, 8, 8, 2, 3, 7, 2, 4, 2, 3, 5, 2, 3, 1, 6, 7, 6, 5, 3, 7,
#        3, 0, 3, 8, 5, 5, 4, 2, 5, 2, 6, 8, 5, 8, 3, 4, 5, 2, 1, 2, 7, 6,
#        0, 0, 0, 2, 7, 0, 7, 5, 4, 8, 2, 7, 5, 0, 0, 8, 8, 2, 3, 3, 5, 2,
#        0, 8, 7, 2, 7, 8, 6, 0, 8, 4, 4, 5, 2, 3, 8, 8, 4, 7, 4, 0, 6, 0,
#        1, 6, 1, 3, 3, 2, 1, 8, 2, 5, 7, 3, 1, 8, 7, 5, 7, 1, 1, 0, 5, 0,
#        5, 0, 4, 4, 6, 5, 6, 5, 8, 3, 8, 8, 4, 6, 5, 2, 2, 3, 2, 7, 0, 7,
#        5, 2, 5, 4, 2, 7, 3, 6, 1, 3, 6, 7, 1, 2, 2, 6, 7, 4, 8, 1, 7, 5,
#        1, 3, 7, 8, 1, 1, 6, 4, 2, 2, 2, 5, 8, 7, 1, 6, 6, 0, 5, 3, 1, 0,
#        7, 4, 4, 3, 5, 1, 7, 0, 5, 1, 0, 3, 4, 2, 8, 1, 6, 0, 3, 6, 2, 6,
#        8, 7, 0, 1, 2, 6, 3, 3, 5, 1, 8, 8, 0, 4, 7, 4, 6, 0, 8, 6, 3, 2,
#        4, 1, 3, 3, 4, 1, 7, 0, 1, 5, 1, 5, 3, 2, 2, 5, 2, 0, 0, 2, 3, 2,
#        7, 6, 5, 5, 2, 5, 3, 2, 2, 1, 5, 4, 2, 6, 0, 2, 3, 3, 1, 4, 6, 6,
#        1, 0, 8, 5, 3, 1, 3, 8, 7, 2, 4, 0, 6, 2, 4, 7, 4, 7, 3, 7, 5, 3,
#        5, 5, 6, 1, 8, 2, 8, 8, 1, 3, 2, 1, 1, 0, 3, 0, 3, 6, 5, 4, 8, 7,
#        0, 3, 3, 1, 6, 4, 3, 7, 6, 5, 8, 5, 8, 6, 4, 4, 0, 6, 5, 6, 6, 1,
#        4, 4, 0, 2, 5, 2, 4, 5, 4, 1, 0, 6, 7, 8, 2, 0, 6, 1, 6, 8, 4, 0,
#        6, 0, 6, 0, 4, 1, 2, 3, 5, 4, 4, 0, 1, 7, 1, 0, 8, 5, 4, 6, 0, 1,
#        5, 3, 5, 1, 4, 1, 6, 3, 8, 3, 8, 1, 6, 8, 4, 3, 5, 7, 2, 5, 5, 6,
#        5, 5, 8, 2, 0, 1, 8, 8, 7, 4, 2, 2, 5, 5, 4, 7, 6, 3, 3, 8, 6, 7,
#        1, 7, 2, 3, 5, 8, 1, 1, 6, 0, 6, 8, 3, 0, 5, 3, 1, 1, 1, 7, 6, 2,
#        7, 2, 0, 1, 4, 6, 7, 3, 2, 4, 7, 7, 6, 2, 5, 7, 0, 3, 7, 3, 4, 0,
#        5, 6, 8, 7, 0, 4, 3, 8, 4, 7, 2, 3, 5, 1, 3, 3, 8, 7, 2, 3, 2, 2,
#        2, 7, 0, 2, 6, 3, 2, 4, 3, 8, 5, 1, 2, 3, 1, 1, 6, 3, 1, 6, 2, 6,
#        8, 8, 7, 4, 5, 7, 3, 4, 5, 2, 3, 8, 6, 1, 7, 4, 3, 0, 0, 5, 7, 2,
#        6, 6, 1, 5, 7, 2, 8, 0, 7, 4, 6, 2, 6, 6, 5, 0, 7, 6, 3, 0, 2, 3,
#        1, 3, 4, 8, 5, 2, 2, 5, 7, 6, 5, 7, 5, 8, 2, 0, 0, 1, 4, 4, 0, 4,
#        6, 3, 8, 2, 1, 5, 4, 2, 8, 2, 1, 1, 6, 7, 0, 8, 7, 6, 1, 0, 0, 3,
#        4, 0, 3, 7, 6, 8, 5, 3, 5, 5, 7, 4, 3, 0, 8, 8, 7, 8, 3, 2, 7, 6,
#        0, 4, 7, 8, 7, 4, 1, 4, 2, 7, 7, 3, 1, 7, 8, 7, 1, 5, 4, 4, 1, 3,
#        6, 5, 5, 2, 1, 1, 6, 2, 3, 4, 7, 5, 4, 3, 7, 3, 2, 4, 1, 2, 7, 6,
#        8, 0, 1, 6, 5, 2, 0, 7, 7, 2, 0, 2, 7, 4, 0, 2, 6, 4, 3, 6, 4, 2,
#        2, 0, 1, 1, 1, 6, 5, 3, 4, 8, 8, 3, 3, 7, 3, 3, 7, 6, 1, 5, 4, 5,
#        8, 5, 6, 0, 5, 0, 0, 6, 5, 3, 8, 8, 7, 3, 2, 1, 1, 2, 6, 5, 1, 4,
#        7, 8, 1, 0, 5, 0, 3, 1, 4, 6, 2, 3, 0, 2, 8, 7, 7, 4, 5, 3, 4, 6,
#        0, 0, 8, 7, 7, 1, 0, 5, 6, 0, 7, 6, 7, 8, 1, 3, 2, 3, 4, 3, 2, 5,
#        8, 8, 0, 3, 4, 6, 3, 0, 2, 1, 4, 4, 6, 5, 1, 4, 7, 7, 7, 8, 6, 8,
#        1, 4, 6, 4, 0, 6, 5, 0, 6, 0, 2, 6, 1, 0, 4, 5, 8, 4, 3, 1, 8, 6,
#        2, 6, 4, 6, 0])

# %%
sc = StandardScaler()
X_train[:, 16:] = sc.fit_transform(X_train[:, 16:])
X_test[:, 16:] = sc.transform(X_test[:, 16:])

# %%
X_train
# Out:
# array([[0.0, 0.0, 1.0, ..., -1.3605606964284784, 0.44001644617005986,
#         0.3396859375552734],
#        [0.0, 0.0, 0.0, ..., 0.4570477288486637, -0.1330944689207881,
#         -0.8376167093765304],
#        [0.0, 1.0, 0.0, ..., 1.9214107004500358, 0.19088036128433855,
#         0.9471908621286248],
#        ...,
#        [1.0, 0.0, 0.0, ..., 1.1282140908326261, -1.363527373274974,
#         -0.45111788667382974],
#        [0.0, 0.0, 0.0, ..., 1.4230134785365869, 1.1060113367601325,
#         1.4918504496771459],
#        [0.0, 0.0, 0.0, ..., 1.640741130893106, -0.9584189500132956,
#         1.2928402157651862]], dtype=object)

# %%
X_test
# Out:
# array([[0.0, 0.0, 0.0, ..., 1.5084346518800003, 0.7904296368712007,
#         0.8759661468338181],
#        [0.0, 0.0, 0.0, ..., -1.2391727132562593, -0.1571547758272138,
#         -0.33380659089414844],
#        [0.0, 0.0, 0.0, ..., 0.9612253309131714, 0.08806451491094991,
#         0.5669765731284065],
#        ...,
#        [0.0, 0.0, 0.0, ..., 0.4795269849916673, -0.8481891718606015,
#         -0.4762560214837617],
#        [0.0, 0.0, 0.0, ..., -1.3656988121183076, -0.6794872525050821,
#         0.5826879073846137],
#        [0.0, 0.0, 0.0, ..., -0.5211210456026042, -1.6305688028352445,
#         -0.7360167478530563]], dtype=object)

# %% [markdown]
# ## Naive Bayes

# %%
start_time = time.time()

model = GaussianNB()
model.fit(X_train, y_train)

nb_training_time = time.time() - start_time
print('Training Time:', nb_training_time)
naive=[0.004, 0.0041, 0.0055, 0.005, 0.006]
# Out:
# Training Time: 0.0050013065338134766

# %%
y_pred = model.predict(X_test)
np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)
# Out:
# array([[7, 7],
#        [0, 0],
#        [7, 7],
#        ...,
#        [4, 4],
#        [6, 6],
#        [0, 0]])

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Accuracy: 0.9190325972660357

# %% [markdown]
# ## Random Forest (RandomForestClassifier)

# %%
rf=[]
rf_store=[1.6908, 1.7149, 1.6753, 1.6596, 1.6712]
ir=range(1,6)

for i in ir:
    start_time = time.time()

    model = RandomForestClassifier(n_estimators = 184, criterion = 'entropy',random_state=1)
    model.fit(X_train, y_train)

    rf_training_time = time.time() - start_time
    print('RF Training Time:', rf_training_time)
    rf.append(rf_training_time)
    i = i+1
rf
# Out:
# RF Training Time: 1.7509832382202148
# RF Training Time: 1.7936677932739258
# RF Training Time: 1.697500228881836
# RF Training Time: 1.6601688861846924
# RF Training Time: 1.7180626392364502
# [1.7509832382202148,
#  1.7936677932739258,
#  1.697500228881836,
#  1.6601688861846924,
#  1.7180626392364502]

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy_score(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
n_estimators_range = range(1, 201)  # Range of number of estimators
ir=range(1,5)
scores = []
rftime = []#256.6548581123352
rftimestore=[256.6549, 220.9796712398529, 191.29112482070923, 190.9539647102356, 191.23814129829407]

for i in ir:
    start_time = time.time()
    # Run the loop over the range of n_estimators

    for n_estimators in n_estimators_range:
        model = RandomForestClassifier(n_estimators = n_estimators, criterion = 'entropy',random_state=1)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)

    rf_time = time.time() - start_time
    rftime.append(rf_time)

rftime
# Out:
# [220.9796712398529, 191.29112482070923, 190.9539647102356, 191.23814129829407]

# %%
plt.plot(n_estimators_range, scores)
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy Score')
plt.title('Accuracy vs Number of Estimators')
plt.show()

# %%
rf_grid = []
ir=range(1,5)
rf_grid_store=[856.1625998020172, 819.738733291626, 791.0501453876495, 1127.1114888191223]

for i in ir:
    start_time = time.time()

    parameter = {'n_estimators': range(1, 201)}
    model = RandomForestClassifier(criterion='entropy', random_state=1)
    grid_search = GridSearchCV(estimator=model, param_grid=parameter, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)
    best_n_estimators = grid_search.best_estimator_.get_params()['n_estimators']
    print(f"The best number of estimators is: {best_n_estimators}")

    rf_gridtime = time.time() - start_time
    rf_grid.append(rf_gridtime)

rf_grid
# Out:
# The best number of estimators is: 192
# The best number of estimators is: 192
# The best number of estimators is: 192
# The best number of estimators is: 192
# [856.1625998020172, 819.738733291626, 791.0501453876495, 1127.1114888191223]

# %% [markdown]
# ## Random Forest (Bagging)

# %%
decisiontree = DecisionTreeClassifier()
model = BaggingClassifier(decisiontree, n_estimators=198, max_samples=0.8, random_state=1)
model.fit(X_train, y_train)
bagging = [1.2, 1.2, 1.2, 1.2, 1.2] #estimator=41  0.951
bagging2= [5.9, 6, 6.1, 6, 5.9]     #estimator=198 0.947

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)


# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.9474237644584648

# %%
n_estimators_range = range(1, 101)  # Range of number of estimators
scores = []
rfbegging_time = []
rfbegging_store=[]
ir=range(1,6)

# Run the loop over the range of n_estimators
for i in ir:
    start_time = time.time()
    
    for n_estimators in n_estimators_range:
        model = BaggingClassifier(DecisionTreeClassifier(), 
                                        n_estimators=n_estimators, 
                                        max_samples=0.8, 
                                        random_state=1)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)

        rf_begtime = time.time() - start_time
        rfbegging_time.append(rf_begtime)

rfbegging_time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\USER\Documents\GitHub\group_resentation_git\1123_LFDgroup_test_withFS.ipynb Cell 32 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> for n_estimators in n_estimators_range:
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=6'>7</a>     model = BaggingClassifier(DecisionTreeClassifier(),
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a>                                      n_estimators=n_estimators,
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=8'>9</a>                                      max_samples=0.8,
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=9'>10</a>                                      random_state=1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=10'>11</a>     model.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=11'>12</a>     y_pred = model.predict(X_test)
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/group_resentation_git/1123_LFDgroup_test_withFS.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a>     score = accuracy_score(y_test, y_pred)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\ensemble\_bagging.py:338, in BaseBagging.fit(self, X, y, sample_weight)
#     329 # Convert data (X is required to be 2d and indexable)
#     330 X, y = self._validate_data(
#     331     X,
#     332     y,
#    (...)
#     336     multi_output=True,
#     337 )
# --> 338 return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\ensemble\_bagging.py:473, in BaseBagging._fit(self, X, y, max_samples, max_depth, sample_weight, check_input)
#     470 seeds = random_state.randint(MAX_INT, size=n_more_estimators)
#     471 self._seeds = seeds
# --> 473 all_results = Parallel(
#     474     n_jobs=n_jobs, verbose=self.verbose, **self._parallel_args()
#     475 )(
#     476     delayed(_parallel_build_estimators)(
#     477         n_estimators[i],
#     478         self,
#     479         X,
#     480         y,
#     481         sample_weight,
#     482         seeds[starts[i] : starts[i + 1]],
#     483         total_n_estimators,
#     484         verbose=self.verbose,
#     485         check_input=check_input,
#     486     )
#     487     for i in range(n_jobs)
#     488 )
#     490 # Reduce
#     491 self.estimators_ += list(
#     492     itertools.chain.from_iterable(t[0] for t in all_results)
#     493 )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\ensemble\_bagging.py:141, in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose, check_input)
#     138         curr_sample_weight[not_indices_mask] = 0
#     140     X_ = X[:, features] if requires_feature_indexing else X
# --> 141     estimator_fit(X_, y, sample_weight=curr_sample_weight)
#     142 else:
#     143     X_ = X[indices][:, features] if requires_feature_indexing else X[indices]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
plt.plot(n_estimators_range, scores)
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy Score')
plt.title('Accuracy vs Number of Estimators')
plt.show()

# %%
parameter = {'n_estimators': range(1, 201)}
decisiontree = DecisionTreeClassifier()
model = BaggingClassifier(decisiontree, max_samples=0.8, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=parameter, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_n_estimators = grid_search.best_estimator_.get_params()['n_estimators']
print(f"The best number of estimators is: {best_n_estimators}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 5
#       3 model = BaggingClassifier(decisiontree, max_samples=0.8, random_state=1)
#       4 grid_search = GridSearchCV(estimator=model, param_grid=parameter, cv=5, scoring='accuracy')
# ----> 5 grid_search.fit(X_train, y_train)
#       6 best_n_estimators = grid_search.best_estimator_.get_params()['n_estimators']
#       7 print(f"The best number of estimators is: {best_n_estimators}")
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\ensemble\_bagging.py:338, in BaseBagging.fit(self, X, y, sample_weight)
#     329 # Convert data (X is required to be 2d and indexable)
#     330 X, y = self._validate_data(
#     331     X,
#     332     y,
#    (...)
#     336     multi_output=True,
#     337 )
# --> 338 return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\ensemble\_bagging.py:473, in BaseBagging._fit(self, X, y, max_samples, max_depth, sample_weight, check_input)
#     470 seeds = random_state.randint(MAX_INT, size=n_more_estimators)
#     471 self._seeds = seeds
# --> 473 all_results = Parallel(
#     474     n_jobs=n_jobs, verbose=self.verbose, **self._parallel_args()
#     475 )(
#     476     delayed(_parallel_build_estimators)(
#     477         n_estimators[i],
#     478         self,
#     479         X,
#     480         y,
#     481         sample_weight,
#     482         seeds[starts[i] : starts[i + 1]],
#     483         total_n_estimators,
#     484         verbose=self.verbose,
#     485         check_input=check_input,
#     486     )
#     487     for i in range(n_jobs)
#     488 )
#     490 # Reduce
#     491 self.estimators_ += list(
#     492     itertools.chain.from_iterable(t[0] for t in all_results)
#     493 )
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\ensemble\_bagging.py:141, in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose, check_input)
#     138         curr_sample_weight[not_indices_mask] = 0
#     140     X_ = X[:, features] if requires_feature_indexing else X
# --> 141     estimator_fit(X_, y, sample_weight=curr_sample_weight)
#     142 else:
#     143     X_ = X[indices][:, features] if requires_feature_indexing else X[indices]
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Kernel SVM (rbf)

# %%
model = SVC(kernel = 'rbf', random_state = 1, C=1, gamma = 0.0001)
model.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.0001, random_state=1)

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [0 4]
#  [1 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.5983175604626709

# %%
model = SVC(kernel='rbf',random_state=1)

parameters = {
              'C': [0.1, 1, 100, 1000],
              'gamma': [0.0001, 0.001, 0.005, 0.1, 1, 3, 5]
             }
gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
gridsearch.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 8
#       3 parameters = {
#       4               'C': [0.1, 1, 100, 1000],
#       5               'gamma': [0.0001, 0.001, 0.005, 0.1, 1, 3, 5]
#       6              }
#       7 gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
# ----> 8 gridsearch.fit(X_train, y_train)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\anaconda3\envs\pythonProject\lib\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
gridsearch.best_params_
# Out:
# {'C': 1, 'gamma': 0.0001}

# %% [markdown]
# ## Kernel SVM (Poly)

# %%
model = SVC(C=0.1, kernel='poly', random_state = 1)
model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, kernel='poly', random_state=1)

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.92534174553102

# %%
model = SVC(kernel='poly',random_state=1)

parameters = {
              'C': [0.1, 1, 100, 1000],
             }
gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
gridsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(kernel='poly', random_state=1),
#              param_grid={'C': [0.1, 1, 100, 1000],
#                          'gamma': [0.0001, 0.001, 0.005, 0.1, 1, 3, 5]})

# %%
gridsearch.best_params_
# Out:
# {'C': 0.1, 'gamma': 0.0001}

# %% [markdown]
# ## Kernel SVM (linear)

# %%
linear = []
ir=range(1, 6)
linear_store=[0.03, 0.029, 0.0289, 0.029, 0.0291]

for i in ir:
    start_time = time.time()
    model = SVC(C=1, kernel='linear', random_state = 1)
    model.fit(X_train, y_train)
    linear_time = time.time() - start_time
    linear.append(linear_time)
linear
# Out:
# [0.0299990177154541,
#  0.029017210006713867,
#  0.028980493545532227,
#  0.029001235961914062,
#  0.029099464416503906]

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[7 7]
#  [0 0]
#  [7 7]
#  ...
#  [4 4]
#  [6 6]
#  [0 0]]

# %%
cm = confusion_matrix(y_test, y_pred)
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

accuracy_score(y_test, y_pred)
# Out:
# 0.9852786540483701

# %%
linear_grid=[]
ir=range(1, 6)
linear_grid_store=[0.9889, 1.0167, 1.0831, 1.0691, 1.0678]

model = SVC(kernel='linear',random_state=1)

for i in ir:
    start_time = time.time()

    parameters = {
                'C': [0.1, 1, 10, 100, 1000],
                }
    gridsearch = GridSearchCV(estimator=model, param_grid=parameters, cv=5)
    gridsearch.fit(X_train, y_train)
    linear_grid_time = time.time() - start_time
    linear_grid.append(linear_grid_time)

linear_grid
# Out:
# [0.9889969825744629,
#  1.01674222946167,
#  1.0831429958343506,
#  1.0691328048706055,
#  1.0678441524505615]

# %%
gridsearch.best_params_
# Out:
# {'C': 1}
